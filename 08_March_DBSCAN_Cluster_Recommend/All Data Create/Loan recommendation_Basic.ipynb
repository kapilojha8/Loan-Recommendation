# %%
import pandas as pd
import numpy as np

# %%
# reading the raw dataset
df = pd.read_csv("Dataset/Clustered_column_on_half_million_record_V1.csv")

# %%
# printing the head of the loan recommend dataset which is in the form of dataframe.
df.head()
# Out:
#                    Id           AccountID  Number_Of_Loans_Granted__c  \
# 0  0060K00000RW5M4QAL  0010K00001fghU0QAI                          75
# 1  0062x00000AkpZnAAJ  0010K00001fghU0QAI                          75
# 2  0062x00000AHV4lAAH  0010K00001fghU0QAI                          75
# 3  0062x000009Ua6WAAS  0010K00001fghU0QAI                          75
# 4  0062x000008zdrUAAQ  0010K00001fghU0QAI                          75
#
#    Num_Of_Loans_Paid__c Purpose_of_Loan__c  Total_Repayments__c  Amount  \
# 0                    73    Living Expenses                    4     200
# 1                    73    Living Expenses                   10     200
# 2                    73    Living Expenses                   10     200
# 3                    73    Living Expenses                   10     200
# 4                    73    Living Expenses                    6     200
#
#    Term_in_Weeks__c Payment_Frequency__c  StageName  Applicant Age  \
# 0             4.571               Weekly  Loan Paid             53
# 1            10.429               Weekly  Loan Paid             53
# 2            11.429               Weekly  Loan Paid             53
# 3            10.286               Weekly  Loan Paid             53
# 4             6.571               Weekly  Loan Paid             53
#
#    summary_income  summary_income_cv        city state    Country  \
# 0          6500.0                NaN  Whittlesea   VIC  Australia
# 1          6500.0           14429.94  Whittlesea   VIC  Australia
# 2          6500.0            9924.14  Whittlesea   VIC  Australia
# 3          6500.0           14683.88  Whittlesea   VIC  Australia
# 4          6500.0            8691.38  Whittlesea   VIC  Australia
#
#    Cluster_result
# 0               0
# 1               1
# 2               1
# 3               1
# 4               2

# %%
df.shape
# Out:
# (514658, 17)

# %%
# Dropping columns because these columns are of no use for use.
# we only need columns like userId, loanId, Amount, Repayment_time, etc.
# StageName ==>  all the StageName are same i.e. "Loan Paid".
# df.drop(["Contact__c", "Min_IT_Loan_ID__c", "Opp_Number__c","StageName"], axis=1,inplace=True)
# IMPORTANT : Here all StageNames were not same we have some variation of stagenames.

# %%
# printing the describe able metric of the dataframe to get few insights about the data
df.describe()
# Out:
#        Number_Of_Loans_Granted__c  Num_Of_Loans_Paid__c  Total_Repayments__c  \
# count               514658.000000         514658.000000        514658.000000
# mean                    12.508102             11.688525             7.633353
# std                      8.276191              8.237319             5.036140
# min                      3.000000              3.000000             1.000000
# 25%                      6.000000              6.000000             5.000000
# 50%                     10.000000              9.000000             6.000000
# 75%                     16.000000             15.000000            10.000000
# max                     75.000000             73.000000            45.000000
#
#               Amount  Term_in_Weeks__c  Applicant Age  summary_income  \
# count  514658.000000     514658.000000  514658.000000    5.146580e+05
# mean      930.842521         11.298860      40.111315    5.820032e+03
# std       857.564911          5.731782      10.658488    2.730689e+05
# min       100.000000        -46.857000       0.000000    0.000000e+00
# 25%       350.000000          7.857000      32.000000    1.213330e+03
# 50%       550.000000         10.000000      39.000000    3.185000e+03
# 75%      1200.000000         14.000000      47.000000    4.333330e+03
# max      5000.000000        153.429000      87.000000    8.714009e+07
#
#        summary_income_cv  Cluster_result
# count       4.920400e+05   514658.000000
# mean        6.497261e+03      102.376343
# std         1.667604e+04      107.592131
# min        -3.782050e+03       -1.000000
# 25%         3.892400e+03       31.000000
# 50%         5.327520e+03       76.000000
# 75%         7.516653e+03      137.000000
# max         8.228670e+06      735.000000

# %% [markdown]
# ### Converting the data into canonical foramt

# %% [markdown]
# It is important to convert the data into a canonical format. We would like to consider data for only those users for this recommendation engine who have taken at least 3 loans and serviced them to completion. Also, we would form data for only those Loan-IDs that have been given at least 5 times. This will ensure that we are working with some amount of data in the system and our recommendation will not be plagued with cold-start problem for our machine model and also, we have some active valid interactions as the basis for this intelligence that we are building.

# %%
# consider data for only those :  
#     --> users taken at least 3 loans & serviced them to completion.  
# df = df[df["Num_Of_Loans_Paid__c"]>=3]
# the minimum value of "Num_Of_Loans_Paid__c" this column is already 3

# %%
# checking for the possibility of null values if null values exists in dataset then we need to handle them 
df.isnull().sum()
# Out:
# Id                                0
# AccountID                         0
# Number_Of_Loans_Granted__c        0
# Num_Of_Loans_Paid__c              0
# Purpose_of_Loan__c               19
# Total_Repayments__c               0
# Amount                            0
# Term_in_Weeks__c                  0
# Payment_Frequency__c              0
# StageName                         0
# Applicant Age                     0
# summary_income                    0
# summary_income_cv             22618
# city                              0
# state                             0
# Country                           0
# Cluster_result                    0
# dtype: int64

# %%
# filling NA values with its mean if they exists

# NA values exists for 3 features Purpose_of_Loan__c, summary_income_cv, city

# %%
# Imputing the feature Purpose_of_Loan_C
# But the feaature is not playing an important role in our system. we can possibly ignore it. 
# But if in case we wanted to impute we can impute using mode
# df['Purpose_of_Loan__c'].fillna(df['Purpose_of_Loan__c'].mode(), inplace=True)

# %%
# Imputing the feature city
# Group by 'state' and fill missing 'city' values with the mode of the corresponding state
df['city'] = df.groupby('state')['city'].transform(lambda x: x.fillna(x.mode().iloc[0]))

# %%
# df['summary_income_cv'].fillna(df['summary_income_cv'].mean(), inplace=True)

# Imputing 0 to the summary_income_cv because it is possible that the field is empty because the user's income is nonexistent.

df.fillna({'summary_income_cv': 0}, inplace=True)

# %%
df.isnull().sum()
# Out:
# Id                             0
# AccountID                      0
# Number_Of_Loans_Granted__c     0
# Num_Of_Loans_Paid__c           0
# Purpose_of_Loan__c            19
# Total_Repayments__c            0
# Amount                         0
# Term_in_Weeks__c               0
# Payment_Frequency__c           0
# StageName                      0
# Applicant Age                  0
# summary_income                 0
# summary_income_cv              0
# city                           0
# state                          0
# Country                        0
# Cluster_result                 0
# dtype: int64

# %%
# describing the dataframe metrices after thansformation (if exists for null values)
df.describe()
# Out:
#        Number_Of_Loans_Granted__c  Num_Of_Loans_Paid__c  Total_Repayments__c  \
# count               514658.000000         514658.000000        514658.000000
# mean                    12.508102             11.688525             7.633353
# std                      8.276191              8.237319             5.036140
# min                      3.000000              3.000000             1.000000
# 25%                      6.000000              6.000000             5.000000
# 50%                     10.000000              9.000000             6.000000
# 75%                     16.000000             15.000000            10.000000
# max                     75.000000             73.000000            45.000000
#
#               Amount  Term_in_Weeks__c  Applicant Age  summary_income  \
# count  514658.000000     514658.000000  514658.000000    5.146580e+05
# mean      930.842521         11.298860      40.111315    5.820032e+03
# std       857.564911          5.731782      10.658488    2.730689e+05
# min       100.000000        -46.857000       0.000000    0.000000e+00
# 25%       350.000000          7.857000      32.000000    1.213330e+03
# 50%       550.000000         10.000000      39.000000    3.185000e+03
# 75%      1200.000000         14.000000      47.000000    4.333330e+03
# max      5000.000000        153.429000      87.000000    8.714009e+07
#
#        summary_income_cv  Cluster_result
# count       5.146580e+05   514658.000000
# mean        6.211721e+03      102.376343
# std         1.635979e+04      107.592131
# min        -3.782050e+03       -1.000000
# 25%         3.691713e+03       31.000000
# 50%         5.180750e+03       76.000000
# 75%         7.376950e+03      137.000000
# max         8.228670e+06      735.000000

# %%
df.head()
# Out:
#                    Id           AccountID  Number_Of_Loans_Granted__c  \
# 0  0060K00000RW5M4QAL  0010K00001fghU0QAI                          75
# 1  0062x00000AkpZnAAJ  0010K00001fghU0QAI                          75
# 2  0062x00000AHV4lAAH  0010K00001fghU0QAI                          75
# 3  0062x000009Ua6WAAS  0010K00001fghU0QAI                          75
# 4  0062x000008zdrUAAQ  0010K00001fghU0QAI                          75
#
#    Num_Of_Loans_Paid__c Purpose_of_Loan__c  Total_Repayments__c  Amount  \
# 0                    73    Living Expenses                    4     200
# 1                    73    Living Expenses                   10     200
# 2                    73    Living Expenses                   10     200
# 3                    73    Living Expenses                   10     200
# 4                    73    Living Expenses                    6     200
#
#    Term_in_Weeks__c Payment_Frequency__c  StageName  Applicant Age  \
# 0             4.571               Weekly  Loan Paid             53
# 1            10.429               Weekly  Loan Paid             53
# 2            11.429               Weekly  Loan Paid             53
# 3            10.286               Weekly  Loan Paid             53
# 4             6.571               Weekly  Loan Paid             53
#
#    summary_income  summary_income_cv        city state    Country  \
# 0          6500.0               0.00  Whittlesea   VIC  Australia
# 1          6500.0           14429.94  Whittlesea   VIC  Australia
# 2          6500.0            9924.14  Whittlesea   VIC  Australia
# 3          6500.0           14683.88  Whittlesea   VIC  Australia
# 4          6500.0            8691.38  Whittlesea   VIC  Australia
#
#    Cluster_result
# 0               0
# 1               1
# 2               1
# 3               1
# 4               2

# %%
len(df['AccountID'].unique()) , len(df['Id'].unique())
# Out:
# (59174, 437242)

# %%
# we need to convert the alpha-numeric AccountID and LoanId into the numeric form because the ALS model only works
#     with int values of loans and users ID.
AccountMapperobj = {ele: count for count, ele in enumerate(sorted(list(set(df['AccountID']))), 1)}
LoanMapperobj = {ele: count for count, ele in enumerate(sorted(list(set(df['Id']))), 1) }

# %%
# creating the dataframe of userId(alpha-numeric) and their unique userIds 
accId,accindex = [],[]
[(accId.append(key),accindex.append(val)) for key,val in AccountMapperobj.items()]
AccountMapperDf = pd.DataFrame({"accountId":accId,
                                "accountIndex":accindex})
# creating the dataframe of loanId(alpha-numeric) and their unique loanIds 
lonId,lonindex = [],[]
[(lonId.append(key),lonindex.append(val)) for key,val in LoanMapperobj.items()]
LoanMapperDf = pd.DataFrame({"LoanId":lonId,
                                "loanIndex":lonindex})

# %%
# saving the loanId and userID so that these loanId and userID could be furter used for same user as our data increases.
import os
# File path to save the userID and loanID
file_path,loan_file_path = r"MappingFiles\AccountMapperDf.csv",r"MappingFiles\LoanMapperDf.csv"

# Check if the file exists
if os.path.exists(file_path) and os.path.exists(loan_file_path):
    # Delete the existing file
    os.remove(file_path)
    os.remove(loan_file_path)
    print(f"File '{file_path} and {loan_file_path}' deleted.")

AccountMapperDf.to_csv(file_path,index=False)
LoanMapperDf.to_csv(loan_file_path,index=False)

print(f"New files '{file_path}' and '{loan_file_path}' created.")
# Out:
# File 'MappingFiles\AccountMapperDf.csv and MappingFiles\LoanMapperDf.csv' deleted.
# New files 'MappingFiles\AccountMapperDf.csv' and 'MappingFiles\LoanMapperDf.csv' created.

# %%
# applying the accountID and loanID for the current dataset. 
df['userId'] = df['AccountID'].map(AccountMapperobj)
df['loanId'] = df['Id'].map(LoanMapperobj)

# %%
# after apply the mapper onto the dataframe preview of dataset
df.head(10)
# Out:
#                    Id           AccountID  Number_Of_Loans_Granted__c  \
# 0  0060K00000RW5M4QAL  0010K00001fghU0QAI                          75
# 1  0062x00000AkpZnAAJ  0010K00001fghU0QAI                          75
# 2  0062x00000AHV4lAAH  0010K00001fghU0QAI                          75
# 3  0062x000009Ua6WAAS  0010K00001fghU0QAI                          75
# 4  0062x000008zdrUAAQ  0010K00001fghU0QAI                          75
# 5  0062x0000047ru6AAA  0010K00001fghU0QAI                          75
# 6  0062x0000047eHtAAI  0010K00001fghU0QAI                          75
# 7  0062x0000037JUeAAM  0010K00001fghU0QAI                          75
# 8  0062x000002ZIPDAA4  0010K00001fghU0QAI                          75
# 9  0062x000002ZDr5AAG  0010K00001fghU0QAI                          75
#
#    Num_Of_Loans_Paid__c Purpose_of_Loan__c  Total_Repayments__c  Amount  \
# 0                    73    Living Expenses                    4     200
# 1                    73    Living Expenses                   10     200
# 2                    73    Living Expenses                   10     200
# 3                    73    Living Expenses                   10     200
# 4                    73    Living Expenses                    6     200
# 5                    73    Living Expenses                   10     200
# 6                    73    Living Expenses                   10     200
# 7                    73    Living Expenses                    6     200
# 8                    73    Living Expenses                    4     200
# 9                    73    Living Expenses                    4     200
#
#    Term_in_Weeks__c Payment_Frequency__c  StageName  Applicant Age  \
# 0             4.571               Weekly  Loan Paid             53
# 1            10.429               Weekly  Loan Paid             53
# 2            11.429               Weekly  Loan Paid             53
# 3            10.286               Weekly  Loan Paid             53
# 4             6.571               Weekly  Loan Paid             53
# 5            10.429               Weekly  Loan Paid             53
# 6             9.857               Weekly  Loan Paid             53
# 7             6.571               Weekly  Loan Paid             53
# 8             4.000               Weekly  Loan Paid             53
# 9             4.000               Weekly  Loan Paid             53
#
#    summary_income  summary_income_cv        city state    Country  \
# 0          6500.0               0.00  Whittlesea   VIC  Australia
# 1          6500.0           14429.94  Whittlesea   VIC  Australia
# 2          6500.0            9924.14  Whittlesea   VIC  Australia
# 3          6500.0           14683.88  Whittlesea   VIC  Australia
# 4          6500.0            8691.38  Whittlesea   VIC  Australia
# 5          6500.0           11736.20  Whittlesea   VIC  Australia
# 6          6500.0           11462.86  Whittlesea   VIC  Australia
# 7          6500.0           10579.48  Whittlesea   VIC  Australia
# 8          6500.0           24283.34  Whittlesea   VIC  Australia
# 9          6500.0           13156.75  Whittlesea   VIC  Australia
#
#    Cluster_result  userId  loanId
# 0               0    1832    4928
# 1               1    1832  257417
# 2               1    1832  222707
# 3               1    1832  195577
# 4               2    1832  167272
# 5               1    1832   98259
# 6               1    1832   97663
# 7               2    1832   92042
# 8               0    1832   78151
# 9               0    1832   77779

# %%
len(df['userId'].unique()) , len(df['loanId'].unique())
# Out:
# (59174, 437242)

# %%
df.describe()
# Out:
#        Number_Of_Loans_Granted__c  Num_Of_Loans_Paid__c  Total_Repayments__c  \
# count               514658.000000         514658.000000        514658.000000
# mean                    12.508102             11.688525             7.633353
# std                      8.276191              8.237319             5.036140
# min                      3.000000              3.000000             1.000000
# 25%                      6.000000              6.000000             5.000000
# 50%                     10.000000              9.000000             6.000000
# 75%                     16.000000             15.000000            10.000000
# max                     75.000000             73.000000            45.000000
#
#               Amount  Term_in_Weeks__c  Applicant Age  summary_income  \
# count  514658.000000     514658.000000  514658.000000    5.146580e+05
# mean      930.842521         11.298860      40.111315    5.820032e+03
# std       857.564911          5.731782      10.658488    2.730689e+05
# min       100.000000        -46.857000       0.000000    0.000000e+00
# 25%       350.000000          7.857000      32.000000    1.213330e+03
# 50%       550.000000         10.000000      39.000000    3.185000e+03
# 75%      1200.000000         14.000000      47.000000    4.333330e+03
# max      5000.000000        153.429000      87.000000    8.714009e+07
#
#        summary_income_cv  Cluster_result         userId         loanId
# count       5.146580e+05   514658.000000  514658.000000  514658.000000
# mean        6.211721e+03      102.376343   25007.805366  212713.377915
# std         1.635979e+04      107.592131   15679.277544  126725.977223
# min        -3.782050e+03       -1.000000       1.000000       1.000000
# 25%         3.691713e+03       31.000000   12379.000000  101996.250000
# 50%         5.180750e+03       76.000000   23979.000000  209102.000000
# 75%         7.376950e+03      137.000000   36451.000000  322502.750000
# max         8.228670e+06      735.000000   59174.000000  437242.000000

# %%
# Out:
# Index(['Id', 'AccountID', 'Number_Of_Loans_Granted__c', 'Num_Of_Loans_Paid__c',
#        'Purpose_of_Loan__c', 'Total_Repayments__c', 'Amount',
#        'Term_in_Weeks__c', 'Payment_Frequency__c', 'StageName',
#        'Applicant Age', 'summary_income', 'summary_income_cv', 'city', 'state',
#        'Country', 'Cluster_result', 'userId', 'loanId'],
#       dtype='object')

# %% [markdown]
# we are working with some amount of data in the system and our recommendation will not be
# plagued with cold-start problem for our machine model and also, we have some active valid interactions as the basis for this intelligence
# that we are building.
# Based on the above description, we can create a representation of user-loan interaction matrix using cumulative data.
#
#
# Cumulative Data Option: Each cell signifying how many times it has been taken. It will be a sum total of all the successful and unsuccessful
# servicing of that specific loan. A negative number would indicate it was served unsuccessfully more than it was served successfully. So, if a
# loan was taken 5 times with 4 of them being serviced successfully and 1 as unsuccessful loan then the overall count should indicate “3” in that
# particular cell (Count = 1 + 1 + 1 + 1 + (-1) = 3).  We will have a “NaN” for not having been taken at all if there is no data for a specific
# user-loan interaction.

# %% [markdown]
# #### we need to update the "Number_Of_Loans_Granted__c" column by decreasing the number by total number of loans row found with "Closed Won-Funded" in the StageName column

# %%
df1 = pd.DataFrame(columns=df.columns)

# %%
for _, group in df.groupby("AccountID"):
    group = pd.DataFrame(group, columns=df.columns)
    
    Cld_Won_Fd_grp = group.loc[group['StageName'] == 'Closed Won-Funded']
    Cld_Won_Pt_Fad_grp = group.loc[group['StageName'] == 'Closed Won-Payment Failed']
    Pt_Pn_grp = group.loc[group['StageName'] == 'Payment Plan']
    Dt_Mt_grp = group.loc[group['StageName'] == 'Debt Management']
    if Cld_Won_Fd_grp.shape[0]>0:
        actual_loans_granted = group.Number_Of_Loans_Granted__c.values[0] - Cld_Won_Fd_grp.shape[0]    
        group['Number_Of_Loans_Granted__c'] = actual_loans_granted
    if Cld_Won_Pt_Fad_grp.shape[0]>0:
        actual_loans_granted = group.Number_Of_Loans_Granted__c.values[0] - Cld_Won_Pt_Fad_grp.shape[0]
        group['Number_Of_Loans_Granted__c'] = actual_loans_granted
    if Pt_Pn_grp.shape[0]>0:
        actual_loans_granted = group.Number_Of_Loans_Granted__c.values[0] - Pt_Pn_grp.shape[0]
        group['Number_Of_Loans_Granted__c'] = actual_loans_granted
    if Dt_Mt_grp.shape[0]>0:
        actual_loans_granted = group.Number_Of_Loans_Granted__c.values[0] - Dt_Mt_grp.shape[0]
        group['Number_Of_Loans_Granted__c'] = actual_loans_granted 
    df1 = pd.concat([df1, group], ignore_index=True)
# Out:
# C:\Users\Ritik.Raghuwanshi\AppData\Local\Temp\ipykernel_4768\828427764.py:20: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df1 = pd.concat([df1, group], ignore_index=True)

# %%
df1.head()
# Out:
#                    Id           AccountID Number_Of_Loans_Granted__c  \
# 0  0062x00000DsEQcAAN  0010K00001ayVHPQA2                         27
# 1  0062x00000ExrNgAAJ  0010K00001ayVHPQA2                         27
# 2  0062x00000471C0AAI  0010K00001ayVHPQA2                         27
# 3  0060K00000QSYfLQAX  0010K00001ayVHPQA2                         27
# 4  0060K00000SvU4QQAV  0010K00001ayVHPQA2                         27
#
#   Num_Of_Loans_Paid__c       Purpose_of_Loan__c Total_Repayments__c Amount  \
# 0                   27  Furniture or Appliances                  10    500
# 1                   27  Furniture or Appliances                  15    500
# 2                   27  Furniture or Appliances                  10    700
# 3                   27         Vehicle Expenses                  10    800
# 4                   27  Furniture or Appliances                  10    800
#
#    Term_in_Weeks__c Payment_Frequency__c          StageName Applicant Age  \
# 0            10.143               Weekly          Loan Paid            55
# 1            14.714               Weekly  Closed Won-Funded            55
# 2            10.000               Weekly          Loan Paid            55
# 3            10.000               Weekly          Loan Paid            55
# 4            10.000               Weekly          Loan Paid            55
#
#    summary_income  summary_income_cv       city state    Country  \
# 0         2166.67            5750.70  Jimboomba   QLD  Australia
# 1         2166.67            6348.38  Jimboomba   QLD  Australia
# 2         2166.67            3901.44  Jimboomba   QLD  Australia
# 3         2166.67               0.00  Jimboomba   QLD  Australia
# 4         2166.67               0.00  Jimboomba   QLD  Australia
#
#   Cluster_result userId  loanId
# 0             16      1  385865
# 1            610      1  416858
# 2            104      1   96163
# 3            106      1     102
# 4            106      1   10278

# %%
df1.shape
# Out:
# (514658, 19)

# %%
df1Copy = df1.copy()

# %%
df1.drop(df1[df1['StageName'] == 'Closed Won-Funded'].index, inplace=True)
df1.drop(df1[df1['StageName'] == 'Debt Management'].index, inplace=True)
df1.drop(df1[df1['StageName'] == 'Payment Plan'].index, inplace=True)
df1.drop(df1[df1['StageName'] ==  'Closed Won-Payment Failed'].index, inplace=True)

# %%
df1['StageName'].value_counts()
# Out:
# StageName
# Loan Paid               467793
# Bad Debt Written Off     11653
# Bad Debt Watch            1052
# Bad Debt Pending           526
# Closed Lost                 23
# Closed Won                  22
# Loan Settled                 1
# Hardship                     1
# Name: count, dtype: int64

# %%
len(df1[df1['StageName'] ==  'Closed Won-Payment Failed'].index)
# Out:
# 0

# %%
df1.to_csv("Check it once V-2.csv", index=False)

# %% [raw]
# # initializing an temp blank dataframe
# dftemp = pd.DataFrame()

# %% [raw]
# df1 = pd.read_csv("./df_data/Check it once V-2.csv")

# %%
df1['StageName'].unique()
# Out:
# array(['Loan Paid', 'Bad Debt Written Off', 'Bad Debt Watch',
#        'Bad Debt Pending', 'Closed Lost', 'Closed Won', 'Loan Settled',
#        'Hardship'], dtype=object)

# %% [raw]
# 'Closed Lost','Bad Debt Written Off','Bad Debt Pending', 'Bad Debt Watch' ===> Red
# 'Loan Paid' ===> Green
# 'Debt Management', 'Payment Plan', 'Closed Won-Payment Failed', 'Closed Won-Funded' === > Orange
#
# "Bank Statements Uploaded", "Loan Amount Offered" ,  "Loan Offer Accepted"

# %%
df1['StageName'].value_counts()
# Out:
# StageName
# Loan Paid               467793
# Bad Debt Written Off     11653
# Bad Debt Watch            1052
# Bad Debt Pending           526
# Closed Lost                 23
# Closed Won                  22
# Loan Settled                 1
# Hardship                     1
# Name: count, dtype: int64

# %%
df1.shape
# Out:
# (481071, 19)

# %% [markdown]
# # Creating the Ratings columns

# %%
# Applying the Cumulative Data Option:sum of all the successful subtraction unsuccessful servicing of specific loan.
df1['count'] = (df1['Num_Of_Loans_Paid__c'] - (df1['Number_Of_Loans_Granted__c'] - df1['Num_Of_Loans_Paid__c']))

# %% [raw]
# # Checking all the possible values of count column
# set(df1['count'])

# %% [raw]
# df1['count'].value_counts()

# %% [raw]
# # Checking all the possible values of count column
# set(df1['count'])

# %%
# creating an function to perform the transformation of count column
#     if count <1                  ==> 0
#     if count >= 1 and count<=10  ==> 1
#     if count >10 and count <100  ==> int(str(x)[0])+1  [43:4, 79:7, 91:9]
#     if count >100                ==> 10
# so by this transformation 0 to 10

def applyRangefunc(x):
    if x<=10 and x>=1:
        return 1
    elif x>10 and x<100:
        return int(str(x)[0])+1
    elif x>=100:
        return 10
    else:
        return x

# %%
# Run this cell only once because if this is runned twice it will convert to false ratings
df1['count'] = df1['count'].apply(lambda x: applyRangefunc(x))
# df['count'] = df['count'].apply(lambda x: 10 if x>100 else x)

# %%
# so checking our transformation of count column so it is in the range of 0 to 10
set(df1['count'])
# Out:
# {0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
df1["count"].value_counts()
# Out:
# count
# 1    264349
# 2    133130
# 3     61981
# 4     17975
# 5      2910
# 6       523
# 7       124
# 8        73
# 0         6
# Name: count, dtype: int64

# %%
# exporting the temp dataframe to an CSV file to use for creating the recommendation model.
df1.to_csv("df_temp_cluster_rating_condition_data.csv",index=False)

# %% [raw]
# # for the making of clusters we are classfying the payment_frequencies into a list
# Payment_Frequency_list = list(set(df1['Payment_Frequency__c']))

# %% [raw]
# # The clusters making according to the Loan Amount and total repayment
# #     (these range of the cluster is been decided with the help of tablue clusters feature)
# # Loan_classify_method = [
# #     {"Cluster" : 1,"ClusterInfo":{"MinAmount":1300,"MaxAmount":2500,"Total_repayment_min":3,"Total_repayment_max":11}},
# #     {"Cluster" : 2,"ClusterInfo":{"MinAmount":200,"MaxAmount":1300,"Total_repayment_min":3,"Total_repayment_max":10}},
# #     {"Cluster" : 3,"ClusterInfo":{"MinAmount":200,"MaxAmount":1400,"Total_repayment_min":10,"Total_repayment_max":16}},
# #     {"Cluster" : 4,"ClusterInfo":{"MinAmount":500,"MaxAmount":1300,"Total_repayment_min":18,"Total_repayment_max":26}},
# #     {"Cluster" : 5,"ClusterInfo":{"MinAmount":1500,"MaxAmount":2600,"Total_repayment_min":19,"Total_repayment_max":26}},
# #     {"Cluster" : 6,"ClusterInfo":{"MinAmount":1450,"MaxAmount":2500,"Total_repayment_min":12,"Total_repayment_max":19}},
# #     {"Cluster" : 7,"ClusterInfo":{"MinAmount":2600,"MaxAmount":3800,"Total_repayment_min":4,"Total_repayment_max":12}},
# #     {"Cluster" : 8,"ClusterInfo":{"MinAmount":3950,"MaxAmount":5000,"Total_repayment_min":4,"Total_repayment_max":12}},
# #     {"Cluster" : 9,"ClusterInfo":{"MinAmount":2800,"MaxAmount":4000,"Total_repayment_min":13,"Total_repayment_max":18}},
# #     {"Cluster" : 10,"ClusterInfo":{"MinAmount":4500,"MaxAmount":5000,"Total_repayment_min":13,"Total_repayment_max":30}},
# #     {"Cluster" : 11,"ClusterInfo":{"MinAmount":2050,"MaxAmount":2500,"Total_repayment_min":27,"Total_repayment_max":32}},
# #     {"Cluster" : 12,"ClusterInfo":{"MinAmount":1700,"MaxAmount":4000,"Total_repayment_min":36,"Total_repayment_max":40}},
# #     {"Cluster" : 13,"ClusterInfo":{"MinAmount":2800,"MaxAmount":4000,"Total_repayment_min":20,"Total_repayment_max":24}},
# #     {"Cluster" : 14,"ClusterInfo":{"MinAmount":3000,"MaxAmount":4000,"Total_repayment_min":30,"Total_repayment_max":36}},
# #     {"Cluster" : 15,"ClusterInfo":{"MinAmount":600,"MaxAmount":1050,"Total_repayment_min":36,"Total_repayment_max":36}}
# # ]
#
# Loan_classify_method = [
#     {"Cluster" : 1,"ClusterInfo":{"MinAmount":100,"MaxAmount":1050,"Total_repayment_min":6,"Total_repayment_max":24}},
#     {"Cluster" : 2,"ClusterInfo":{"MinAmount":1050,"MaxAmount":2300,"Total_repayment_min":10,"Total_repayment_max":19}},
#     {"Cluster" : 3,"ClusterInfo":{"MinAmount":4400,"MaxAmount":5000,"Total_repayment_min":12,"Total_repayment_max":18}},
#     {"Cluster" : 4,"ClusterInfo":{"MinAmount":500,"MaxAmount":2250,"Total_repayment_min":19,"Total_repayment_max":27}},
#     {"Cluster" : 5,"ClusterInfo":{"MinAmount":400,"MaxAmount":2500,"Total_repayment_min":28,"Total_repayment_max":40}},
#     {"Cluster" : 6,"ClusterInfo":{"MinAmount":100,"MaxAmount":1150,"Total_repayment_min":1,"Total_repayment_max":8}},
#     {"Cluster" : 7,"ClusterInfo":{"MinAmount":1100,"MaxAmount":2200,"Total_repayment_min":1,"Total_repayment_max":9}},
#     {"Cluster" : 8,"ClusterInfo":{"MinAmount":2350,"MaxAmount":3250,"Total_repayment_min":11,"Total_repayment_max":18}},
#     {"Cluster" : 9,"ClusterInfo":{"MinAmount":4400,"MaxAmount":5000,"Total_repayment_min":19,"Total_repayment_max":26}},
#     {"Cluster" : 10,"ClusterInfo":{"MinAmount":4650,"MaxAmount":5000,"Total_repayment_min":28,"Total_repayment_max":36}},
#     {"Cluster" : 11,"ClusterInfo":{"MinAmount":2750,"MaxAmount":3400,"Total_repayment_min":18,"Total_repayment_max":28}},
#     {"Cluster" : 12,"ClusterInfo":{"MinAmount":2250,"MaxAmount":3200,"Total_repayment_min":1,"Total_repayment_max":10}},
#     {"Cluster" : 13,"ClusterInfo":{"MinAmount":4400,"MaxAmount":5000,"Total_repayment_min":2,"Total_repayment_max":11}},
#     {"Cluster" : 14,"ClusterInfo":{"MinAmount":3300,"MaxAmount":4400,"Total_repayment_min":11,"Total_repayment_max":18}},
#     {"Cluster" : 15,"ClusterInfo":{"MinAmount":3250,"MaxAmount":4300,"Total_repayment_min":1,"Total_repayment_max":10}},
#     {"Cluster" : 16,"ClusterInfo":{"MinAmount":2200,"MaxAmount":2750,"Total_repayment_min":19,"Total_repayment_max":28}},
#     {"Cluster" : 17,"ClusterInfo":{"MinAmount":3500,"MaxAmount":4350,"Total_repayment_min":19,"Total_repayment_max":26}},
#     {"Cluster" : 18,"ClusterInfo":{"MinAmount":3400,"MaxAmount":4300,"Total_repayment_min":28,"Total_repayment_max":33}},
#     {"Cluster" : 19,"ClusterInfo":{"MinAmount":2050,"MaxAmount":3100,"Total_repayment_min":29,"Total_repayment_max":45}},
#     {"Cluster" : 20,"ClusterInfo":{"MinAmount":3450,"MaxAmount":4500,"Total_repayment_min":35,"Total_repayment_max":38}}
# ]

# %% [raw]
# # applying the clusters to the dataframe.
#
# for cluster in Loan_classify_method:
#     cluster_id = cluster['Cluster']
#     cluster_info_minAmount,cluster_info_maxAmount,cluster_info_total_replayment_min,cluster_info_total_replayment_max = cluster['ClusterInfo']['MinAmount'], cluster['ClusterInfo']['MaxAmount'], cluster['ClusterInfo']['Total_repayment_min'], cluster['ClusterInfo']['Total_repayment_max']
#     dfM =  df1[(((df1['Amount']>=cluster_info_minAmount) &
#                  (df1['Amount']<=cluster_info_maxAmount)) &
#                 ((df1['Total_Repayments__c']>=cluster_info_total_replayment_min) &
#                  (df1['Total_Repayments__c']<=cluster_info_total_replayment_max)))].copy()
#     dfM['LoanIdFormat'] = cluster_id
#     # for pfl in range(len(Payment_Frequency_list)):
#     #     dfPR = dfM[(dfM['Payment_Frequency__c']==Payment_Frequency_list[pfl])].copy()
#     #     dfPR.drop(dfPR.index, inplace=True)
#     dfM['LoanIdFormat'] = cluster_id
#     dftemp = pd.concat([dftemp, dfM], ignore_index=True)
#     dfM.drop(dfM.index, inplace=True)

# %% [raw]
# dftemp[dftemp['userId']==1].sort_values(by="loanId").shape

# %% [raw]
# df1[df1['userId']==1].sort_values(by="loanId").shape

# %% [raw]
# dftemp.shape

# %% [raw]
# # exporting the temp dataframe to an CSV file to use for creating the recommendation model.
# dftemp.to_csv("df_temp_cluster_rating_condition_data.csv",index=False)
